# %%
import requests
import pandas as pd

# %%
API_KEY = "YOUR_API_KEY"

# %%
city = "Lagos"

url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"

response = requests.get(url)

print(response.status_code)
# Out:
# 200

# %%
data = response.json()

print(data)
# Out:
# {'coord': {'lon': 3.75, 'lat': 6.5833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 24.48, 'feels_like': 25.41, 'temp_min': 24.48, 'temp_max': 24.48, 'pressure': 1015, 'humidity': 93, 'sea_level': 1015, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 1.6, 'deg': 234, 'gust': 4.5}, 'clouds': {'all': 85}, 'dt': 1787269109, 'sys': {'country': 'NG', 'sunrise': 1787290756, 'sunset': 1787335050}, 'timezone': 3600, 'id': 2332453, 'name': 'Lagos', 'cod': 200}

# %%
cities = [
    "Lagos", "London", "New York", "Paris", "Tokyo",
    "Dubai", "Toronto", "Sydney", "Cape Town", "Cairo",
    "Nairobi", "Accra", "Johannesburg", "Berlin", "Madrid",
    "Rome", "Mumbai", "Singapore", "Los Angeles", "Chicago"
]

# %%
weather_data = []

for city in cities:
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"

    response = requests.get(url)
    data = response.json()

    weather_data.append({
        "City Name": data["name"],
        "Temperature (°C)": data["main"]["temp"],
        "Humidity (%)": data["main"]["humidity"],
        "Weather Condition": data["weather"][0]["description"],
        "Wind Speed (m/s)": data["wind"]["speed"],
        "Date and Time": data["dt"]
    })

# %%
df = pd.DataFrame(weather_data)

df
# Out:
#        City Name  Temperature (°C)  Humidity (%)     Weather Condition  \
# 0          Lagos             24.48            93       overcast clouds
# 1         London             15.63            79         broken clouds
# 2       New York             18.95            95  heavy intensity rain
# 3          Paris             17.92            75         broken clouds
# 4          Tokyo             29.25            72         broken clouds
# 5          Dubai             34.96            63      scattered clouds
# 6        Toronto             21.75            59      scattered clouds
# 7         Sydney             18.51            70       overcast clouds
# 8      Cape Town             13.73            79      scattered clouds
# 9          Cairo             25.42            65             clear sky
# 10       Nairobi             14.93            77         broken clouds
# 11         Accra             25.23            88         broken clouds
# ...

# %%
df = df.rename(columns={
    "City Name": "City",
    "Temperature (°C)": "Temperature_C",
    "Humidity (%)": "Humidity_Percent",
    "Weather Condition": "Weather_Condition",
    "Wind Speed (m/s)": "Wind_Speed",
    "Date and Time": "Date_Time"
})

df
# Out:
#             City  Temperature_C  Humidity_Percent     Weather_Condition  \
# 0          Lagos          24.48                93       overcast clouds
# 1         London          15.63                79         broken clouds
# 2       New York          18.95                95  heavy intensity rain
# 3          Paris          17.92                75         broken clouds
# 4          Tokyo          29.25                72         broken clouds
# 5          Dubai          34.96                63      scattered clouds
# 6        Toronto          21.75                59      scattered clouds
# 7         Sydney          18.51                70       overcast clouds
# 8      Cape Town          13.73                79      scattered clouds
# 9          Cairo          25.42                65             clear sky
# 10       Nairobi          14.93                77         broken clouds
# 11         Accra          25.23                88         broken clouds
# ...

# %%
df.dtypes
# Out:
# City                  object
# Temperature_C        float64
# Humidity_Percent       int64
# Weather_Condition     object
# Wind_Speed           float64
# Date_Time              int64
# dtype: object

# %%
df["Date_Time"] = pd.to_datetime(df["Date_Time"], unit="s")

# %%
df
# Out:
#             City  Temperature_C  Humidity_Percent     Weather_Condition  \
# 0          Lagos          24.48                93       overcast clouds
# 1         London          15.63                79         broken clouds
# 2       New York          18.95                95  heavy intensity rain
# 3          Paris          17.92                75         broken clouds
# 4          Tokyo          29.25                72         broken clouds
# 5          Dubai          34.96                63      scattered clouds
# 6        Toronto          21.75                59      scattered clouds
# 7         Sydney          18.51                70       overcast clouds
# 8      Cape Town          13.73                79      scattered clouds
# 9          Cairo          25.42                65             clear sky
# 10       Nairobi          14.93                77         broken clouds
# 11         Accra          25.23                88         broken clouds
# ...

# %%
df.dtypes
# Out:
# City                         object
# Temperature_C               float64
# Humidity_Percent              int64
# Weather_Condition            object
# Wind_Speed                  float64
# Date_Time            datetime64[ns]
# dtype: object

# %%
df.to_csv("weather_data.csv", index=False)

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'weather_data.csv', 'sample_data']

# %%
weather_df = pd.read_csv("weather_data.csv")

weather_df.head()
# Out:
#        City  Temperature_C  Humidity_Percent     Weather_Condition  \
# 0     Lagos          24.48                93       overcast clouds
# 1    London          15.63                79         broken clouds
# 2  New York          18.95                95  heavy intensity rain
# 3     Paris          17.92                75         broken clouds
# 4     Tokyo          29.25                72         broken clouds
#
#    Wind_Speed            Date_Time
# 0        1.60  2026-08-20 23:48:41
# 1        3.80  2026-08-20 23:46:46
# 2       13.86  2026-08-20 23:50:32
# 3        2.06  2026-08-20 23:44:01
# 4        5.66  2026-08-20 23:42:30

# %%
temperature_comparison = df[["City", "Temperature_C"]].sort_values(
    by="Temperature_C",
    ascending=False
)

temperature_comparison
# Out:
#             City  Temperature_C
# 5          Dubai          34.96
# 15          Rome          31.92
# 18   Los Angeles          30.68
# 4          Tokyo          29.25
# 16        Mumbai          27.99
# 17     Singapore          27.96
# 9          Cairo          25.42
# 11         Accra          25.23
# 0          Lagos          24.48
# 19       Chicago          23.72
# 14        Madrid          23.51
# 6        Toronto          21.75
# 2       New York          18.95
# 7         Sydney          18.51
# 3          Paris          17.92
# 13        Berlin          16.27
# 1         London          15.63
# 10       Nairobi          14.93
# 8      Cape Town          13.73
# 12  Johannesburg           9.94

# %%
top_3_humidity = df.nlargest(3, "Humidity_Percent")

print(top_3_humidity[["City", "Humidity_Percent"]])
# Out:
#         City  Humidity_Percent
# 2   New York                95
# 0      Lagos                93
# 11     Accra                88

# %%
weather_conditions = df[["City", "Weather_Condition"]]

weather_conditions
# Out:
#             City     Weather_Condition
# 0          Lagos       overcast clouds
# 1         London         broken clouds
# 2       New York  heavy intensity rain
# 3          Paris         broken clouds
# 4          Tokyo         broken clouds
# 5          Dubai      scattered clouds
# 6        Toronto      scattered clouds
# 7         Sydney       overcast clouds
# 8      Cape Town      scattered clouds
# 9          Cairo             clear sky
# 10       Nairobi         broken clouds
# 11         Accra         broken clouds
# 12  Johannesburg             clear sky
# 13        Berlin         broken clouds
# 14        Madrid         broken clouds
# 15          Rome         broken clouds
# 16        Mumbai            light rain
# 17     Singapore            few clouds
# 18   Los Angeles         broken clouds
# 19       Chicago            few clouds

# %%
weather_summary = df["Weather_Condition"].value_counts()

weather_summary
# Out:
# Weather_Condition
# broken clouds           9
# scattered clouds        3
# overcast clouds         2
# few clouds              2
# clear sky               2
# heavy intensity rain    1
# light rain              1
# Name: count, dtype: int64

# %%
df['City'].nunique()
# Out:
# 20

# %% [markdown]
# **Summary of Findings**
#
# Temperature: Dubai was the hottest city in the dataset, with a temperature of 35.96°C, followed by Rome at 34.92°C and Los Angeles at 31.80°C. Johannesburg recorded the lowest temperature at 10.94°C.
# Humidity: Lagos recorded the highest humidity at 92%, followed by Accra at 88% and Singapore at 86%.
# Weather Conditions: Broken clouds was the most common weather condition, recorded in 9 out of the 20 cities. Overcast clouds occurred in 3 cities, while scattered clouds, few clouds, and clear sky each occurred in 2 cities. Moderate rain and light rain were each recorded in 1 city.
# Overall: The data shows noticeable differences in weather conditions across the selected cities. Dubai had the highest temperature, Lagos had the highest humidity, and broken clouds was the dominant weather condition in the dataset.
